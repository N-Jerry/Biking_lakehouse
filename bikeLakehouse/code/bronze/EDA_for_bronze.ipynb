# %%
df = spark.read.table('biking_product_sales_lakehouse.bronze.customer_erp')
df.display()

# %%
from pyspark.sql.functions import *
df2 = spark.read.table('biking_product_sales_lakehouse.bronze.customer_crm')
df2.filter(col('cst_key') == 'NASAW0011053').display()
