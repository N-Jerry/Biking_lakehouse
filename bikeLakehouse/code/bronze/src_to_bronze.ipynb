# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
from bronze_config import files

# %%
print(type(files))

# %%
table_loc = 'biking_product_sales_lakehouse.bronze'
for key, file in files.items():
    df = (spark.read
            .option('header', 'true')
            .option('inferSchema', 'true')
            .csv(file)
        )
    
    df.write.mode('overwrite').saveAsTable(f'{table_loc}.{key}')
