# %%
df_cust = spark.read.table("biking_product_sales_lakehouse.bronze.customer_crm")

df_cust.display()

# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import col
#SELECTING ONLY MALE CUSTOMERS
df_cust.filter(col('cst_gndr') == 'M').display()

# %%
spark.read.table('biking_product_sales_lakehouse.bronze.customer_erp').display()

# %%
df_cust.groupBy('cst_gndr').agg(F.count("*").alias("gender count"), F.count('cst_lastname')).display()
